# %% [markdown]
# <a href="https://colab.research.google.com/github/Farida02/learn-data-science-/blob/NLP/Breakoutroom_Text_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Breakoutroom Teks Analitik

# %% [markdown]
# Gunakan indo_dataset pada breakoutroom, ambil 1000 baris pertama, lalu gunakan 2 label saja, yaitu label happy dan label sadness. Kemudian lakukan preprocessing data pada data dengan kedua label tersebut.

# %% [markdown]
# Label happy termasuk tweet positif sedangkan label sadness termasuk tweet negatif.

# %% [markdown]
# Ada berapa baris data dengan dua label tersebut?

# %% [markdown]
# Apakah tweet positif lebih banyak dibandingkan tweet negatif?

# %% [markdown]
# ### Preprocessing Data
# Dalam Preprocessing data teks dengan kasus klasifikasi maka cleaning yang akan dilakukan diantaranya dengan normalisasi data dengan cara sebagai berikut
# 1. Lower/Upper casing
# 2. Menghilangkan pattern atau karakter yang tidak diperlukan
# 3. Tokenization
# 4. Lemmatization
# 5. Stemming
# 6. Menghilangkan Stopword

# %% [markdown]
# Lower case

# %% [markdown]
# Menghilangkan pattern atau karakter yang tidak diperlukan

# %% [markdown]
# Tokenization

# %% [markdown]
# Apakah ada perbedaan banyaknya kata-kata yang digunakan dalam tweet positif dan negatif?

# %% [markdown]
# Lemmatization

# %% [markdown]
# Stemming

# %% [markdown]
# Stopwords

# %% [markdown]
# Tunjukkan wordcloud tweet positif dan tweet negatif

# %% [markdown]
# Apakah ada perbadaan penggunaan kata pada masing-masing label?

# %% [markdown]
# Bagaimana akurasi model dengan Multinomial Naive Bayes dan n_gram?
# mana yang lebih baik?
